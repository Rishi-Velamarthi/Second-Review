# %% [markdown]
# CODE FOR WEB AUTOMATION

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
import pandas as pd
import numpy as np
from selenium.common.exceptions import NoSuchElementException

# %%
df=pd.read_csv("E:\DD_stations\stations - Sheet1.csv")
df1=df[:][1316:]
df1=df1.reset_index().drop('index',axis=1)
df1
# Out:
#      Network Station code query                      Name      Country  \
# 0         IX         CMP3   NaN    Station Campagna Italy        Italy
# 1         IV         CMPO   NaN               Campotto Po        Italy
# 2         IT          CMR   NaN               CASTELMAURO        Italy
# 3         KO         CMRD   NaN      Camardi Nigde Turkey       Turkey
# 4         IT         CMRN   NaN                  CAMERINO        Italy
# ...      ...          ...   ...                       ...          ...
# 2412      IV         ZOVE  2412                 Zovencedo        Italy
# 2413      IT          ZPP  2413        ZOLA PREDOSA PIANA        Italy
# 2414      QZ          ZSN  2414  Zaisan Kazakhstan SNECCA   Kazakhstan
# 2415      CH          ZUR  2415      Zuerich Degenried ZH  Switzerland
# 2416       A          ZYT  2416      Istanbul-Zeytinburnu       Turkey
#
#                     Municipality  Latitude  Longitude Vs30/EC8 estimation  \
# ...

# %%
network=df1['Network'].values
station=df1['Station code'].values
forms=df1['Waveforms'].values

# %%
opt=Options()
opt.add_experimental_option("debuggerAddress","localhost:9000")
driver= webdriver.Chrome(chrome_options=opt,executable_path="E:\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_27484\327992700.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome(chrome_options=opt,executable_path="E:\chromedriver_win32\chromedriver.exe")
# C:\Users\rishi\AppData\Local\Temp\ipykernel_27484\327992700.py:3: DeprecationWarning: use options instead of chrome_options
#   driver= webdriver.Chrome(chrome_options=opt,executable_path="E:\chromedriver_win32\chromedriver.exe")

# %%
load_time=7
recordlimit=85
wait_time=15
new_urls=[]
urls={}
j=0

# %%
stopped=2399

# %%
errors=['7C','XO','Z3','1J','HI','4A','XE','3A','ZO','XK','X3','ZH','Y1','HA']

for i in range(stopped+1,len(df1)):
    
    print("https://esm-db.eu/#/station/"+network[i]+'/'+station[i])
    
    ##SPECIAL CASES
    
    #if network[i] =='4C':
    # 
    #    continue
    
    if forms[i] > 85:# or  network[i] in errors:
        
        new_urls.append((forms[i],i,"https://esm-db.eu/#/station/"+network[i]+'/'+station[i]))
        
        continue
        
        #stopped=i
        
        #driver.get(url)
        
        #time.sleep(0.5)
        
        #play=driver.find_element(by=By.XPATH,value='//*[@id="movie_player"]/div[34]/div[2]/div[1]/button')
    
    
        #play.click()
    
        #break
        
    url='https://www.youtube.com/watch?v=YBHQbu5rbdQ'
    
    driver.get(url)
    
    time.sleep(0.2)
    
    url="https://esm-db.eu/#/station/"+network[i]+'/'+station[i]
    
    driver.get(url)
    
    #Locating buttons using HTML
    
    #Error handling in locating buttons:
        
    try :
        
        time.sleep(7)
        
        records=driver.find_element(by=By.LINK_TEXT,value='Records')
        
    except NoSuchElementException:
        
        print("Trying to locate Element for: "+ url)
        
        try :
        
            driver.get('https://www.youtube.com/watch?v=YBHQbu5rbdQ')
            
            driver.refresh()
            
            driver.get(url)
            
            time.sleep(15)
        
            records=driver.find_element(by=By.LINK_TEXT,value='Records')
        
        except NoSuchElementException:
        
            try:
            
                print("Trying to locate Element for: "+ url)
            
                time.sleep(60)
                
                records=driver.find_element(by=By.LINK_TEXT,value='Records')
                
            
            except NoSuchElementException:
                
                    
                    driver.get('https://www.youtube.com/watch?v=16y1AkoZkmQ')
                    
                    time.sleep(0.5)
                    
                    play=driver.find_element(by=By.XPATH,value='//*[@id="movie_player"]/div[29]/div[2]/div[1]/button')
                    
                    play.click()
                    
                    print("Element NOT FOUND")
                    
                    break
                    
    #Locating buttons using HTML
    
    quality=driver.find_element(by=By.XPATH,value='//*[@id="bad_quality"]/div/div[2]')
    
    velocity=driver.find_element(by=By.XPATH,value='//*[@id="station-tab-6"]/div/div[4]/div[1]/table[1]/tbody/tr[6]/td[2]/p-checkbox/div/div[2]')
    
    displacement=driver.find_element(by=By.XPATH,value='//*[@id="station-tab-6"]/div/div[4]/div[1]/table[1]/tbody/tr[7]/td[2]/p-checkbox/div/div[2]')
    
    export=driver.find_element(by=By.XPATH,value='//*[@id="execute"]')
    
    # clicking the Buttons
    
    records.click() 
    
    time.sleep(load_time)
    
    quality.click()

    velocity.click()

    displacement.click()
    
    export.click()
    
    time.sleep(1)
# Out:
# https://esm-db.eu/#/station/KO/YUVA
# Trying to locate Element for: https://esm-db.eu/#/station/KO/YUVA
# Trying to locate Element for: https://esm-db.eu/#/station/KO/YUVA
# https://esm-db.eu/#/station/HI/ZAK1
# Trying to locate Element for: https://esm-db.eu/#/station/HI/ZAK1
# Trying to locate Element for: https://esm-db.eu/#/station/HI/ZAK1
# Element NOT FOUND

# %%
(stopped,i,forms[i])
# Out:
# (2398, 2400, 26.0)

# %%
stopped =i-1

# %%
urls={20.0: 'https://esm-db.eu/#/station/4A/MI02',
 10.0: 'https://esm-db.eu/#/station/4A/MI03',
 2.0: 'https://esm-db.eu/#/station/XO/MN08',
 19.0: 'https://esm-db.eu/#/station/4A/MI05',
 93.0: 'https://esm-db.eu/#/station/IV/MIDA',
 156.0: 'https://esm-db.eu/#/station/RO/MLR',
 94.0: 'https://esm-db.eu/#/station/IT/MMP1',
 136.0: 'https://esm-db.eu/#/station/IV/MMUR',
 4.0: 'https://esm-db.eu/#/station/XO/MN06',
 3.0: 'https://esm-db.eu/#/station/XO/MN09',
 200.0: 'https://esm-db.eu/#/station/GE/MNAI'}

# %%
new_urls=[(205.0, 1099, 'https://esm-db.eu/#/station/HI/MYT1'),
 (1.0, 1102, 'https://esm-db.eu/#/station/3A/MZ03'),
 (14.0, 1103, 'https://esm-db.eu/#/station/3A/MZ04'),
 (1.0, 1104, 'https://esm-db.eu/#/station/3A/MZ05'),
 (1.0, 1105, 'https://esm-db.eu/#/station/3A/MZ06'),
 (1.0, 1106, 'https://esm-db.eu/#/station/3A/MZ07'),
 (20.0, 1107, 'https://esm-db.eu/#/station/3A/MZ08'),
 (1.0, 1108, 'https://esm-db.eu/#/station/3A/MZ09'),
 (19.0, 1109, 'https://esm-db.eu/#/station/3A/MZ10'),
 (15.0, 1110, 'https://esm-db.eu/#/station/3A/MZ102'),
 (20.0, 1111, 'https://esm-db.eu/#/station/3A/MZ11'),
 (20.0, 1112, 'https://esm-db.eu/#/station/3A/MZ12'),
 (17.0, 1113, 'https://esm-db.eu/#/station/3A/MZ14'),
 (1.0, 1114, 'https://esm-db.eu/#/station/3A/MZ15'),
 (1.0, 1115, 'https://esm-db.eu/#/station/3A/MZ16'),
 (19.0, 1116, 'https://esm-db.eu/#/station/3A/MZ19'),
 (19.0, 1117, 'https://esm-db.eu/#/station/3A/MZ21'),
 (22.0, 1118, 'https://esm-db.eu/#/station/3A/MZ24'),
 (22.0, 1119, 'https://esm-db.eu/#/station/3A/MZ26'),
 (22.0, 1120, 'https://esm-db.eu/#/station/3A/MZ27'),
 (22.0, 1121, 'https://esm-db.eu/#/station/3A/MZ28'),
 (15.0, 1122, 'https://esm-db.eu/#/station/3A/MZ29'),
 (15.0, 1123, 'https://esm-db.eu/#/station/3A/MZ30'),
 (6.0, 1124, 'https://esm-db.eu/#/station/3A/MZ31'),
 (22.0, 1125, 'https://esm-db.eu/#/station/3A/MZ50'),
 (22.0, 1126, 'https://esm-db.eu/#/station/3A/MZ51'),
 (1.0, 1127, 'https://esm-db.eu/#/station/3A/MZ52'),
 (17.0, 1128, 'https://esm-db.eu/#/station/3A/MZ61'),
 (17.0, 1129, 'https://esm-db.eu/#/station/3A/MZ63'),
 (339.0, 1141, 'https://esm-db.eu/#/station/HI/NAX1'),
 (158.0, 1142, 'https://esm-db.eu/#/station/KO/NAZL'),
 (92.0, 1151, 'https://esm-db.eu/#/station/IT/NCR'),
 (281.0, 1165, 'https://esm-db.eu/#/station/HL/NISR'),
 (283.0, 1168, 'https://esm-db.eu/#/station/HL/NOAC'),
 (249.0, 1178, 'https://esm-db.eu/#/station/HI/NPS1'),
 (115.0, 1181, 'https://esm-db.eu/#/station/IV/NRCA'),
 (94.0, 1194, 'https://esm-db.eu/#/station/HL/NVR'),
 (110.0, 1206, 'https://esm-db.eu/#/station/KO/ODEM'),
 (105.0, 1258, 'https://esm-db.eu/#/station/KO/ORLT'),
 (103.0, 1267, 'https://esm-db.eu/#/station/IV/OSSC'),
 (3.0, 1273, 'https://esm-db.eu/#/station/HI/OUR1'),
 (1.0, 1281, 'https://esm-db.eu/#/station/HI/PAL1'),
 (17.0, 1291, 'https://esm-db.eu/#/station/HI/PAT1'),
 (10.0, 1292, 'https://esm-db.eu/#/station/HI/PAT2'),
 (8.0, 1293, 'https://esm-db.eu/#/station/HI/PAT3'),
 (612.0, 1296, 'https://esm-db.eu/#/station/HL/PATC'),
 (447.0, 1297, 'https://esm-db.eu/#/station/HL/PATG'),
 (86.0, 1300, 'https://esm-db.eu/#/station/IT/PCB'),
 (127.0, 1303, 'https://esm-db.eu/#/station/IV/PCRO'),
 (186.0, 1305, 'https://esm-db.eu/#/station/MN/PDG'),
 (5.0, 1309, 'https://esm-db.eu/#/station/ZO/PDN3'),
 (7.0, 1310, 'https://esm-db.eu/#/station/ZO/PDN4'),
 (5.0, 1311, 'https://esm-db.eu/#/station/ZO/PDN5'),
 (6.0, 1312, 'https://esm-db.eu/#/station/ZO/PDN6'),
 (4.0, 1313, 'https://esm-db.eu/#/station/ZO/PDN7'),
 (2.0, 1314, 'https://esm-db.eu/#/station/ZO/PDN8'),
 (87.0, 1315, 'https://esm-db.eu/#/station/HP/PDO'),
 (540.0, 1316, 'https://esm-db.eu/#/station/G/PEL'),
 (2.0, 1317, 'https://esm-db.eu/#/station/HI/PEL1'),
 (89.0, 1323, 'https://esm-db.eu/#/station/RO/PETR'),
 (105.0, 1332, 'https://esm-db.eu/#/station/AC/PHP'),
 (98.0, 1336, 'https://esm-db.eu/#/station/IV/PIEI'),
 (91.0, 1338, 'https://esm-db.eu/#/station/IV/PIGN'),
 (103.0, 1339, 'https://esm-db.eu/#/station/IV/PIO1'),
 (196.0, 1346, 'https://esm-db.eu/#/station/HL/PLG'),
 (76.0, 1348, 'https://esm-db.eu/#/station/HI/PLN1'),
 (126.0, 1350, 'https://esm-db.eu/#/station/RO/PLOR'),
 (124.0, 1354, 'https://esm-db.eu/#/station/RO/PLOR4'),
 (93.0, 1381, 'https://esm-db.eu/#/station/IV/POFI'),
 (8.0, 1385, 'https://esm-db.eu/#/station/HI/POL1'),
 (115.0, 1395, 'https://esm-db.eu/#/station/IV/PP3'),
 (4.0, 1402, 'https://esm-db.eu/#/station/HI/PRE1'),
 (306.0, 1408, 'https://esm-db.eu/#/station/HL/PRK'),
 (232.0, 1420, 'https://esm-db.eu/#/station/HL/PSRA'),
 (157.0, 1443, 'https://esm-db.eu/#/station/HP/PVO'),
 (88.0, 1456, 'https://esm-db.eu/#/station/HP/PYL'),
 (482.0, 1457, 'https://esm-db.eu/#/station/HI/PYL1'),
 (24.0, 1472, 'https://esm-db.eu/#/station/HI/PYR1'),
 (2.0, 1473, 'https://esm-db.eu/#/station/HI/PYR2'),
 (2.0, 1474, 'https://esm-db.eu/#/station/HI/PYR3'),
 (371.0, 1500, 'https://esm-db.eu/#/station/HI/RDI1'),
 (256.0, 1509, 'https://esm-db.eu/#/station/HI/RGE1'),
 (627.0, 1515, 'https://esm-db.eu/#/station/HL/RIOA'),
 (97.0, 1544, 'https://esm-db.eu/#/station/IV/RM33'),
 (100.0, 1551, 'https://esm-db.eu/#/station/IV/RNI2'),
 (2.0, 1556, 'https://esm-db.eu/#/station/HI/ROD1'),
 (4.0, 1557, 'https://esm-db.eu/#/station/HI/ROD2'),
 (265.0, 1558, 'https://esm-db.eu/#/station/CL/ROD3'),
 (3.0, 1559, 'https://esm-db.eu/#/station/HI/ROD3'),
 (1.0, 1560, 'https://esm-db.eu/#/station/HI/ROD4'),
 (462.0, 1562, 'https://esm-db.eu/#/station/HL/RODB'),
 (115.0, 1564, 'https://esm-db.eu/#/station/IV/ROM9'),
 (123.0, 1594, 'https://esm-db.eu/#/station/IV/SACS'),
 (177.0, 1614, 'https://esm-db.eu/#/station/GE/SALTA'),
 (320.0, 1620, 'https://esm-db.eu/#/station/G/SANVU'),
 (4.0, 1626, 'https://esm-db.eu/#/station/HI/SAR1'),
 (109.0, 1724, 'https://esm-db.eu/#/station/IV/SEF1'),
 (2.0, 1730, 'https://esm-db.eu/#/station/XK/SELL'),
 (163.0, 1737, 'https://esm-db.eu/#/station/IV/SENI'),
 (1.0, 1743, 'https://esm-db.eu/#/station/HI/SER1'),
 (128.0, 1744, 'https://esm-db.eu/#/station/HP/SERG'),
 (138.0, 1755, 'https://esm-db.eu/#/station/IV/SFI'),
 (111.0, 1757, 'https://esm-db.eu/#/station/HI/SFL1'),
 (3.0, 1769, 'https://esm-db.eu/#/station/XO/SGF3'),
 (86.0, 1770, 'https://esm-db.eu/#/station/IV/SGG'),
 (115.0, 1778, 'https://esm-db.eu/#/station/IT/SGPA'),
 (121.0, 1783, 'https://esm-db.eu/#/station/IT/SGSC'),
 (131.0, 1795, 'https://esm-db.eu/#/station/KO/SHAP'),
 (1.0, 2260, 'https://esm-db.eu/#/station/KO/TVSB'),
 (106.0, 2269, 'https://esm-db.eu/#/station/KO/UKOP'),
 (99.0, 2275, 'https://esm-db.eu/#/station/G/UNM'),
 (93.0, 2279, 'https://esm-db.eu/#/station/IV/VAGA'),
 (3.0, 2285, 'https://esm-db.eu/#/station/HI/VAR1'),
 (20.0, 2288, 'https://esm-db.eu/#/station/HI/VAS1'),
 (378.0, 2289, 'https://esm-db.eu/#/station/HI/VAS2'),
 (4.0, 2304, 'https://esm-db.eu/#/station/HI/VER1'),
 (1.0, 2319, 'https://esm-db.eu/#/station/HA/VILL'),
 (91.0, 2332, 'https://esm-db.eu/#/station/HL/VLMS'),
 (133.0, 2350, 'https://esm-db.eu/#/station/RO/VOIR'),
 (1.0, 2352, 'https://esm-db.eu/#/station/HI/VOL1'),
 (306.0, 2353, 'https://esm-db.eu/#/station/HI/VOL2'),
 (164.0, 2357, 'https://esm-db.eu/#/station/EU/VRI'),
 (2.0, 2361, 'https://esm-db.eu/#/station/HI/VRO1'),
 (92.0, 2386, 'https://esm-db.eu/#/station/HA/XLKS'),
 (7.0, 2388, 'https://esm-db.eu/#/station/KO/YARM'),
 (1.0, 2389, 'https://esm-db.eu/#/station/KO/YAYO'),
 (320.0, 2390, 'https://esm-db.eu/#/station/HL/YDRA'),
 (78.0, 2391, 'https://esm-db.eu/#/station/KO/YENI'),
 (273.0, 2392, 'https://esm-db.eu/#/station/KO/YKAV'),
 (10.0, 2393, 'https://esm-db.eu/#/station/KO/YKBL'),
 (9.0, 2395, 'https://esm-db.eu/#/station/KO/YLVH'),
 (6.0, 2398, 'https://esm-db.eu/#/station/KO/YUNK'),
 (31.0, 2399, 'https://esm-db.eu/#/station/KO/YUVA'),
 (26.0, 2400, 'https://esm-db.eu/#/station/HI/ZAK1')]

# %%
sums=0
for n in new_urls:
    sums+=n[0]

# %%
new_urls
# Out:
# [(205.0, 1099, 'https://esm-db.eu/#/station/HI/MYT1'),
#  (1.0, 1102, 'https://esm-db.eu/#/station/3A/MZ03'),
#  (14.0, 1103, 'https://esm-db.eu/#/station/3A/MZ04'),
#  (1.0, 1104, 'https://esm-db.eu/#/station/3A/MZ05'),
#  (1.0, 1105, 'https://esm-db.eu/#/station/3A/MZ06'),
#  (1.0, 1106, 'https://esm-db.eu/#/station/3A/MZ07'),
#  (20.0, 1107, 'https://esm-db.eu/#/station/3A/MZ08'),
#  (1.0, 1108, 'https://esm-db.eu/#/station/3A/MZ09'),
#  (19.0, 1109, 'https://esm-db.eu/#/station/3A/MZ10'),
#  (15.0, 1110, 'https://esm-db.eu/#/station/3A/MZ102'),
#  (20.0, 1111, 'https://esm-db.eu/#/station/3A/MZ11'),
#  (20.0, 1112, 'https://esm-db.eu/#/station/3A/MZ12'),
#  (17.0, 1113, 'https://esm-db.eu/#/station/3A/MZ14'),
#  (1.0, 1114, 'https://esm-db.eu/#/station/3A/MZ15'),
#  (1.0, 1115, 'https://esm-db.eu/#/station/3A/MZ16'),
#  (19.0, 1116, 'https://esm-db.eu/#/station/3A/MZ19'),
#  (19.0, 1117, 'https://esm-db.eu/#/station/3A/MZ21'),
# ...

# %%
sums*0.6
# Out:
# 8083.799999999999
